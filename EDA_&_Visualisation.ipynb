# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohithtechis/Data-processing-Assignment/blob/main/EDA_%26_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def create_sample_chart():
  x_series=np.arange(10)
  y_series=x**2
  plt.plot(x_series,y_series)
  plt.title('string title')
  plt.xlable('X axis')
  plt.ylable('Y axis')
plt.show()

# %%
x=np.arange(0,10,0.1)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/weather_2012.csv',parse_dates=True, index_col='Date/Time')
df.head()
# Out:
#                      Temp (C)  ...               Weather
# Date/Time                      ...
# 2012-01-01 00:00:00      -1.8  ...                   Fog
# 2012-01-01 01:00:00      -1.8  ...                   Fog
# 2012-01-01 02:00:00      -1.8  ...  Freezing Drizzle,Fog
# 2012-01-01 03:00:00      -1.5  ...  Freezing Drizzle,Fog
# 2012-01-01 04:00:00      -1.5  ...                   Fog
#
# [5 rows x 7 columns]

# %%
data =df.groupby(df.index.month).mean()
data.head(3)
# Out:
#            Temp (C)  Dew Point Temp (C)  ...  Visibility (km)  Stn Press (kPa)
# Date/Time                                ...
# 1         -7.371505          -12.294758  ...        22.100269       101.005349
# 2         -4.225000           -9.221695  ...        25.182184       101.142414
# 3          3.121237           -3.488575  ...        26.177957       101.335255
#
# [3 rows x 6 columns]

# %%
x=data.index
y=data['Temp (C)']
plt.plot(x,y)
plt.title('Temp Trend,2012')
plt.xlabel('Month')
plt.ylabel('Temp (c)')
plt.show()

# %%
import calendar
calendar_months=calendar.month_name[1:]
print(calendar_months)

# %%
data['calendar']=calendar_months
df=data.set_index('calendar',drop=False)
df.head(3)
# Out:
#           Temp (C)  Dew Point Temp (C)  ...  Stn Press (kPa)  calendar
# calendar                                ...
# January  -7.371505          -12.294758  ...       101.005349   January
# February -4.225000           -9.221695  ...       101.142414  February
# March     3.121237           -3.488575  ...       101.335255     March
#
# [3 rows x 7 columns]

# %%
x=df.index
y=df['Temp (C)']
plt.plot(x,y)
plt.title('Temp Trend,2012')
plt.xlabel('Month')
plt.ylabel('Temp (c)')
plt.show()

# %%
x=df.index
y=df['Temp (C)']
plt.plot(x,y)
plt.title('Temp Trend,2012')
plt.xlabel('Month')
plt.ylabel('Temp (c)')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import calendar

def bar_plot():
    weekly_data = weather_df.groupby(weather_df.index.dayofweek).mean()
    
    plt.bar(weekly_data.index, weekly_data['Visibility (km)'])

    plt.title('Visibility by week, 2012')
    plt.xlabel('Day of week')
    plt.ylabel('Visibility (km)')

    plt.xticks(weekly_data.index, calendar.day_abbr, rotation=45)

    plt.show()
    bar_plot()

# %%
x=np.arange(0,10,0.1)
y1=(((x-3)**3)-100)+np.random.randint(-20,20, size=len(x))
plt.hist(y1)
plt.show()

# %%
x=data['Wind Spd (km/h)']
plt.hist(x)
plt.show()

# %%
x=np.arange(0,10,0.1)
y=np.exp(x)
plt.boxplot(y)
plt.show()

# %%
x=data['Wind Spd (km/h)']
plt.boxplot(x)
plt.show()

# %%
x=np.arange(0,10,0.1)
y1=(((x-3)**3)-100)+np.random.randint(-20,20,size=len(x))
y2=(((3-x)**3)+50)+np.random.randint(-20,20, size=len(x))
plt.scatter(x,y1, c='r')
plt.scatter(x,y2,c='b')
plt.show()

# %%
data.head()
# Out:
#             Temp (C)  Dew Point Temp (C)  ...  Stn Press (kPa)  calendar
# Date/Time                                 ...
# 1          -7.371505          -12.294758  ...       101.005349   January
# 2          -4.225000           -9.221695  ...       101.142414  February
# 3           3.121237           -3.488575  ...       101.335255     March
# 4           7.009306           -1.934583  ...       100.716833     April
# 5          16.237769            8.080780  ...       101.057164       May
#
# [5 rows x 7 columns]

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2,'b.-')
ax.plot(x,x**2.5,'g--')
ax.plot(x,x**3,c='r')
fig.show()

# %%
def two_plots():
  x=np.array([0,1,2,3,4,5])
  y=x**2
  fig=plt.figure()
  axes1=fig.add_axes([0.1,0.1,0.8,0.8])
  axes2=fig.add_axes([0.2,0.5,0.4,0.3])
  axes1.plot(x,y,'b')
  axes1.set_title('axes 1')
  axes2.plot(x,y,'r')
  axes2.set_title('axes 2')
two_plots()

# %%
axes=plt.subplots(nrows=2, ncols=2)

# %%
axes=plt.subplots(2,2)
x=np.arange(1,10,0.1)
y=x**2
axes[0].plot(x**2,x)
axes[0].set_title('A1')
axes[1].plot()
axes[2].plot()
axes[3].plot(x,y)
axes[3].set_title('A3')

# %%
import seaborn as sns
sns.distplot(data['Wind Spd (km/h)'], bins=25)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import pandas as pd
import numpy as np
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack','Lee','David','Gasper','Betina','Andres']),
     'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
     'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}
df=pd.DataFrame(d)
print(df)
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %%
print(df.mean())
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %%
print(df.median())
# Out:
# Age       29.50
# Rating     3.79
# dtype: float64

# %%
print(df)
print('\n')
print(df.mode())
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65
#
#
#       Name   Age  Rating
# 0   Andres  23.0    2.56
# 1   Betina  25.0    2.98
# 2    David  30.0    3.20
# 3   Gasper   NaN    3.24
# 4     Jack   NaN    3.65
# 5    James   NaN    3.78
# 6      Lee   NaN    3.80
# 7    Ricky   NaN    3.98
# 8    Smith   NaN    4.10
# 9    Steve   NaN    4.23
# 10     Tom   NaN    4.60
# 11     Vin   NaN    4.80

# %%
df.mode(axis=0)
# Out:
#       Name   Age  Rating
# 0   Andres  23.0    2.56
# 1   Betina  25.0    2.98
# 2    David  30.0    3.20
# 3   Gasper   NaN    3.24
# 4     Jack   NaN    3.65
# 5    James   NaN    3.78
# 6      Lee   NaN    3.80
# 7    Ricky   NaN    3.98
# 8    Smith   NaN    4.10
# 9    Steve   NaN    4.23
# 10     Tom   NaN    4.60
# 11     Vin   NaN    4.80

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    23
# 1    25
# 2    30
# dtype: int64

# %%
print(df.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
mu=0
variance=1
sigma=math.sqrt(variance)
x=np.linspace(mu-3*sigma,mu+3*sigma,100)
plt.plot(x,stats.norm.pdf(x,mu,sigma))

# %%
import pandas as pd 
md=pd.read_csv('/content/auto-mpg.csv')
md
# Out:
#       mpg  cylinders  ...  origin                   car name
# 0    18.0          8  ...       1  chevrolet chevelle malibu
# 1    15.0          8  ...       1          buick skylark 320
# 2    18.0          8  ...       1         plymouth satellite
# 3    16.0          8  ...       1              amc rebel sst
# 4    17.0          8  ...       1                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...       1            ford mustang gl
# 394  44.0          4  ...       2                  vw pickup
# 395  32.0          4  ...       1              dodge rampage
# 396  28.0          4  ...       1                ford ranger
# 397  31.0          4  ...       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
md.describe()
# Out:
#               mpg   cylinders  ...  model year      origin
# count  398.000000  398.000000  ...  398.000000  398.000000
# mean    23.514573    5.454774  ...   76.010050    1.572864
# std      7.815984    1.701004  ...    3.697627    0.802055
# min      9.000000    3.000000  ...   70.000000    1.000000
# 25%     17.500000    4.000000  ...   73.000000    1.000000
# 50%     23.000000    4.000000  ...   76.000000    1.000000
# 75%     29.000000    8.000000  ...   79.000000    2.000000
# max     46.600000    8.000000  ...   82.000000    3.000000
#
# [8 rows x 7 columns]

# %%
md.corr()
# Out:
#                    mpg  cylinders  ...  model year    origin
# mpg           1.000000  -0.775396  ...    0.579267  0.563450
# cylinders    -0.775396   1.000000  ...   -0.348746 -0.562543
# displacement -0.804203   0.950721  ...   -0.370164 -0.609409
# weight       -0.831741   0.896017  ...   -0.306564 -0.581024
# acceleration  0.420289  -0.505419  ...    0.288137  0.205873
# model year    0.579267  -0.348746  ...    1.000000  0.180662
# origin        0.563450  -0.562543  ...    0.180662  1.000000
#
# [7 rows x 7 columns]

# %%
md['mpg'].corr(md['weight'])
# Out:
# -0.8317409332443352

# %%
md.drop(['model year','origin'],axis=1).corr(method='spearman')
# Out:
#                    mpg  cylinders  displacement    weight  acceleration
# mpg           1.000000  -0.821864     -0.855692 -0.874947      0.438677
# cylinders    -0.821864   1.000000      0.911876  0.873314     -0.474189
# displacement -0.855692   0.911876      1.000000  0.945986     -0.496512
# weight       -0.874947   0.873314      0.945986  1.000000     -0.404550
# acceleration  0.438677  -0.474189     -0.496512 -0.404550      1.000000

# %%
import matplotlib.pyplot as plt
md.drop(['model year','origin'],axis=1).corr(method='pearson').style.format('{:.2}').background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style  type="text/css" >
# #T_aeb383a2_20cd_11ec_996f_0242ac1c0002row0_col0,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row1_col1,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row2_col2,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row3_col3,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row4_col4{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row0_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row0_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row0_col3,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row1_col0,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row2_col0,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row3_col0,#T_aeb383a2_20cd_11ec_996f_0242ac1c0002row4_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
md.cov()
# Out:
#                       mpg    cylinders  ...  model year      origin
# mpg             61.089611   -10.308911  ...   16.741163    3.532185
# cylinders      -10.308911     2.893415  ...   -2.193499   -0.767477
# displacement  -655.402318   168.623214  ... -142.717137  -50.964989
# weight       -5505.211745  1290.695575  ... -959.946344 -394.639330
# acceleration     9.058930    -2.370842  ...    2.938105    0.455354
# model year      16.741163    -2.193499  ...   13.672443    0.535790
# origin           3.532185    -0.767477  ...    0.535790    0.643292
#
# [7 rows x 7 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df=pd.read_csv('/content/train.csv')
df.head()

# %%
df.info()

# %%
df2=df[[column for column in df if df[column].count()/ len(df)>=0.3]]
del df2['Id']
print('List of dropped columns:',end=" ")
for c in df.columns:
  if c not in df2.columns:
    print(c, end=" ")
print('\n')
df=df2
# Out:
# List of dropped columns: Id Alley PoolQC Fence MiscFeature

# %%
print(df['SalePrice'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('int64'), dtype('O')]

# %%
df_num=df.select_dtypes(include=['float64','int64'])
df_num.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  MoSold  YrSold  SalePrice
# 0          60         65.0     8450  ...       2    2008     208500
# 1          20         80.0     9600  ...       5    2007     181500
# 2          60         68.0    11250  ...       9    2008     223500
# 3          70         60.0     9550  ...       2    2006     140000
# 4          60         84.0    14260  ...      12    2008     250000
#
# [5 rows x 37 columns]

# %%
df_num.hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df_num_corr=df_num.corr()['SalePrice'][:-1]
golden_features_list=df_num_corr[abs(df_num_corr)>0.5].sort_values(ascending=False)
print('there is {} strongly correlated values with SalePrice:\n{}'.format(len(golden_features_list), golden_features_list))

# %%
for i in range(0, len(df_num.columns),5):
  sns.pairplot(data=df_num,
               x_vars=df_num.columns[i:i+5],
               y_vars=["SalePrice"])

# %%
import operator
individual_features_df = []
for i in range(0, len(df_num.columns) - 1):
    tmpDf = df_num[[df_num.columns[i], 'SalePrice']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)
all_correlations = {feature.columns[0]: feature.corr()['SalePrice'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
#    KitchenAbvGr: -0.13920069217785566
#        HalfBath: -0.08439171127179887
#      MSSubClass: -0.08428413512659523
#     OverallCond: -0.0778558940486776
#          YrSold: -0.028922585168730426
#    BsmtHalfBath: -0.028834567185481712
#        PoolArea: -0.014091521506356928
#    BsmtFullBath: 0.011439163340408634
#          MoSold: 0.04643224522381936
#       3SsnPorch: 0.06393243256889079
#     OpenPorchSF: 0.08645298857147708
#         MiscVal: 0.08896338917298924
#      Fireplaces: 0.1216605842136395
#       BsmtUnfSF: 0.16926100049514192
#    BedroomAbvGr: 0.18093669310849045
#      WoodDeckSF: 0.19370601237520677
#      BsmtFinSF2: 0.19895609430836586
#   EnclosedPorch: 0.2412788363011751
#     ScreenPorch: 0.25543007954878405
#         LotArea: 0.2638433538714063
#    LowQualFinSF: 0.3000750165550133
#     LotFrontage: 0.35179909657067854
#      MasVnrArea: 0.4340902197568926
#      BsmtFinSF1: 0.4716904265235731
#     GarageYrBlt: 0.48636167748786213
# ...

# %%
golden_features_list = [key for key, value in all_correlations if abs(value) >= 0.5]
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 11 strongly correlated values with SalePrice:
# ['YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd', 'FullBath', '1stFlrSF', 'GarageArea', 'TotalBsmtSF', 'GarageCars', '2ndFlrSF', 'GrLivArea', 'OverallQual']

# %%
corr = df_num.drop('SalePrice', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
quantitative_features_list = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', '1stFlrSF',
    '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 
    'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']
df_quantitative_values = df[quantitative_features_list]
df_quantitative_values.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  ...  PoolArea  MiscVal  SalePrice
# 0         65.0     8450       196.0  ...         0        0     208500
# 1         80.0     9600         0.0  ...         0        0     181500
# 2         68.0    11250       162.0  ...         0        0     223500
# 3         60.0     9550         0.0  ...         0        0     140000
# 4         84.0    14260       350.0  ...         0        0     250000
#
# [5 rows x 28 columns]

# %%
features_to_analyse = [x for x in quantitative_features_list if x in golden_features_list]
features_to_analyse.append('SalePrice')
features_to_analyse
# Out:
# ['TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %%
fig, ax = plt.subplots(round(len(features_to_analyse) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse) - 1:
        sns.regplot(x=features_to_analyse[i],y='SalePrice', data=df[features_to_analyse], ax=ax)

# %%
categorical_features = [a for a in quantitative_features_list[:-1] + df.columns.tolist() if (a not in quantitative_features_list[:-1]) or (a not in df.columns.tolist())]
df_categ = df[categorical_features]
df_categ.head()
# Out:
#    MSSubClass MSZoning Street  ... SaleType SaleCondition SalePrice
# 0          60       RL   Pave  ...       WD        Normal    208500
# 1          20       RL   Pave  ...       WD        Normal    181500
# 2          60       RL   Pave  ...       WD        Normal    223500
# 3          70       RL   Pave  ...       WD       Abnorml    140000
# 4          60       RL   Pave  ...       WD        Normal    250000
#
# [5 rows x 49 columns]

# %%
df_not_num = df_categ.select_dtypes(include = ['O'])
print('There is {} non numerical features including:\n{}'.format(len(df_not_num.columns), df_not_num.columns.tolist()))
# Out:
# There is 39 non numerical features including:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='BsmtExposure', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %%
plt.figure(figsize = (12, 6))
ax = sns.boxplot(x='SaleCondition', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %%
fig, axes = plt.subplots(round(len(df_not_num.columns) / 3), 3, figsize=(12, 30))
for i, ax in enumerate(fig.axes):
    if i < len(df_not_num.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
        sns.countplot(x=df_not_num.columns[i], alpha=0.7, data=df_not_num, ax=ax)
fig.tight_layout()

# %%
a=pd.DataFrame([23,45,54,22,67,23,12])
a.median()
a.mean()
# Out:
# 0    20.293091
# dtype: float64

# %%
a=pd.DataFrame([38, 32, 10, 12, 20])
b=pd.DataFrame([19,11,17,4,24])
a.std()
# Out:
# 0    12.280065
# dtype: float64
